# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu
# vi của nó.

# %%
a, b = float(input())
dientich = a * b
chuvi = (a + b) * 2
print(dientich, chuvi)

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của
# nó.

# %%
from math import *
r = float(input())
dientich = pi * ( r ** 2)
chuvi = 2 * pi * r
print(f'{dientich:.2f}')
print(f'{chuvi:.2f}')
# Out:
# 28.27
# 18.85

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là
# độ dài ba cạnh hay không, nếu  không thì in  ra màn  hình  'Khong la ba  canh
# cua mot tam  giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân,
# Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn
# hình.

# %%
a, b, c = map(float, input().split())
if  a + b > c or a + c > b or b + c >a:
    p = ( a + b + c)* (1/2)
    dientich = (p*(p-a)*(p-b)*(p-c))**(1/2)
    chuvi = a + b + c
    if a == b == c:
        print(f'{dientich:.2f}')
        print(f'{chuvi:.2f}')
        print('Đây là tam giác đều')
    elif a == b or a == c or b == c:
        print(f'{dientich:.2f}')
        print(f'{chuvi:.2f}')
        print('Đây là tam giác cân')
    elif (a**2) + (b**2) == (c**2) or (a**2) + (c**2) == (b**2) or (b**2) + (c**2) == (a**2):
        print(f'{dientich:.2f}')
        print(f'{chuvi:.2f}')
        print('Đây là tam giác vuông')
    else:
        print(f'{dientich:.2f}')
        print(f'{chuvi:.2f}')
        print('Đây là tam giác đều')
else:
    print('Không là ba cạnh của một tam giác')
# Out:
# 0.43
# 3.00
# Đây là tam giác đều

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input().split())
no = (-b)/a
print(f'phương trình bấc nhất có dạng: {a}x + {b} = 0')
print(f'Phương trình có nghiệm:', f'{no:.2f}')
# Out:
# phương trình bấc nhất có dạng: 2.0x + 4.0 = 0
# Phương trình có nghiệm: -2.00

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c = map(float, input().split())
delta = (b**2) - (4 * a * c)
if delta > 0:
    x1 = (-b + (delta**(1/2)))/(2*a)
    x2 = (-b - (delta**(1/2)))/(2*a)
    print('Phương trình có 2 nghiệm phân biệt')
    print(f'{x1:.2f}')
    print(f'{x2:.2f}')
elif delta == 0:
    x = (-b)/(2**a)
    print(f'Phương trình có nghiệm kép:' f'{x:.2f}')
else:
    print('Phương trình vô nghiệm')
# Out:
# Phương trình có 2 nghiệm phân biệt
# 4.00
# 3.00

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a, b, c, d = map(float, input().split())
print(max(a, b, c, d))
# Out:
# 9.0

# %%
a, b, c, d = map(float, input().split())
danhsach = [a,b,c,d]
for i in danhsach:
    if i - a >= 0 and i - b >= 0 and i - c >= 0 and i - c >= 0 and i - d >= 0:
        print(i)
# Out:
# 7.0

# %%
danhsach = []
while True:
    a = input()
    if a == 'x':
        break
    danhsach.append(float(a))
if len(danhsach) > 0 :
    lonnhat = danhsach[0]
    for i in range(1, len(danhsach)):
        if danhsach[i] > lonnhat:
            lonnhat = danhsach[i]
    print(lonnhat)
else:
    print('Vui lòng nhập các số cần so sánh')
# Out:
# 4.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
danhsach = []
while True:
    a = input()
    if a == 'x':
        break
    danhsach.append(float(a))
if len(danhsach) > 0 :
    lonnhat = danhsach[0]
    for i in range(1, len(danhsach)):
        if danhsach[i] < lonnhat:
            lonnhat = danhsach[i]
    print(lonnhat)
else:
    print('Vui lòng nhập các số cần so sánh')
# Out:
# 1.0

# %%
danhsach = []
while True:
    a = input()
    if a == 'x':
        break
    danhsach.append(float(a))
print(min(danhsach))
# Out:
# 1.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by = m
# cx + dy = n

# %%
a, b, m, c, d, n = map(float, input().split())
y = (m - (n * (a/c)))/(b-(d*(a/c)))
x = (m-(b*y))/a
print(f'{x:.2f}')
print(f'{y:.2f}')
# Out:
# -1.00
# 2.00

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết
# ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao
# nhiêu giây.

# %%
x = int(input())
a = x // 3600
b = ( x % 3600 ) // 60
c = x % 60
if b != 0:
    if a != 0:
        print(f'{a} giờ, {b} phút, {c} giây')
    else:
        print(f'{b} phút, {c} giây')
else:
    print(f'{x} giây')
# Out:
# 1 giờ, 6 phút, 40 giây

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một
# điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
#giả sử tâm đường tròn nằm tại gốc tọa độ
x, y = map(float, input('Nhập tọa độ của điểm A').split())
r = float(input('Nhập bán kính của hình tròn'))
if (((x**2) + (y**2))**(1/2)) == r:
    print('Điểm A có tọa độ', f'{x},{y}' 'thuộc đường tròn')
else:
    print('Điểm A nằm trong hoặc nằm ngoài đường tròn')
# Out:
# Điểm A nằm trong hoặc nằm ngoài đường tròn

# %% [markdown]
# Bài 11: Tính x lũy thừa y (Với x, y là số thực).

# %%
x, y = map(float, input().split())
s = x**y
print('giá trị cần tìm là: ' f'{s:.2f}')
# Out:
# giá trị cần tìm là: 8.00
